# %%
import requests
from requests.auth import HTTPBasicAuth
link = "https://www.udemy.com/api-2.0/courses/?page=1&page_size=12"
print("Search")
x = input()
new_link = link +"&search="+x
print(new_link)
response = requests.get(new_link,auth = HTTPBasicAuth('DmcabxNiiVj5slAK8ycd4F7Te7jySRezaZYfr4RS', 'pDdWt1Yw0bno9vMslAIAjelMIC95QuTHG3LBjB7rDUpMlpV2fkNpnQnD3MBR8QMoeAos0lzI06HSqz4lHDXflQQrYQbQdyiWJNVxqK0hjH8BQPwxYMl9BjixJTSaoTOa'))
print(response.json())
# Out:
# Search
#  piano
# https://www.udemy.com/api-2.0/courses/?page=1&page_size=12&search=piano
# {'count': 2568, 'next': 'https://www.udemy.com/api-2.0/courses/?page=2&page_size=12&search=piano', 'previous': None, 'results': [{'_class': 'course', 'id': 238934, 'title': 'Pianoforall - Incredible New Way To Learn Piano & Keyboard', 'url': '/course/pianoforall-incredible-new-way-to-learn-piano-keyboard/', 'is_paid': True, 'price': '$84.99', 'price_detail': {'amount': 84.99, 'currency': 'USD', 'price_string': '$84.99', 'currency_symbol': '$'}, 'price_serve_tracking_id': 'YUdUKmPMSYGTpKtE1lISPA', 'visible_instructors': [{'_class': 'user', 'id': 5753906, 'title': 'Robin Hall', 'name': 'Robin', 'display_name': 'Robin Hall', 'job_title': 'Piano Teacher (300,000 students online), Artist, Therapist,', 'image_50x50': 'https://img-c.udemycdn.com/user/50x50/5753906_1b3f_4.jpg', 'image_100x100': 'https://img-c.udemycdn.com/user/100x100/5753906_1b3f_4.jpg', 'initials': 'RH', 'url': '/user/robinhall3/'}], 'image_125_H': 'https://img-b.udemycdn.com/course/125_H/238934_4d81_7.jpg?secure=KauF1SCY-VZGxGBl2EVcdA%3D%3D%2C1644935151', 'image_240x135': 'https://img-b.udemycdn.com/course/240x135/238934_4d81_7.jpg?secure=Fuvl6qDBdgB40qwuUb5Xng%3D%3D%2C1644935151', 'is_practice_test_course': False, 'image_480x270': 'https://img-b.udemycdn.com/course/480x270/238934_4d81_7.jpg?secure=xfFRhgfo67_LKH0Eu1XdPA%3D%3D%2C1644935151', 'published_title': 'pianoforall-incredible-new-way-to-learn-piano-keyboard', 'tracking_id': 'EbIgfOZwSIO2fzqrYRqW8w', 'predictive_score': None, 'relevancy_score': None, 'input_features': None, 'lecture_search_result': None, 'curriculum_lectures': [], 'order_in_results': None, 'curriculum_items': [], 'headline': 'Learn Piano in WEEKS not years. Play-By-Ear & learn to Read Music. Pop, Blues, Jazz, Ballads, Improvisation, Classical', 'instructor_name': None}, {'_class': 'course', 'id': 1111630, 'title': 'Learn piano or keyboard from scratch - Complete piano course', 'url': '/course/learn-to-play-the-piano-from-scratch/', 'is_paid': True, 'price': '$84.99', 'price_detail': {'amount': 84.99, 'currency': 'USD', 'price_string': '$84.99', 'currency_symbol': '$'}, 'price_serve_tracking_id': 'ofLdNA29RK6JwOFWdfssaQ', 'visible_instructors': [{'_class': 'user', 'id': 27222306, 'title': 'Martin Cohen', 'name': 'Martin', 'display_name': 'Martin Cohen', 'job_title': 'Teacher, musician and composer', 'image_50x50': 'https://img-c.udemycdn.com/user/50x50/27222306_006d.jpg', 'image_100x100': 'https://img-c.udemycdn.com/user/100x100/27222306_006d.jpg', 'initials': 'MC', 'url': '/user/martin-cohen-2/'}], 'image_125_H': 'https://img-b.udemycdn.com/course/125_H/1111630_c4ba_5.jpg?secure=qns_Gigjyn2fQ8cDRvJRzA%3D%3D%2C1644935151', 'image_240x135': 'https://img-b.udemycdn.com/course/240x135/1111630_c4ba_5.jpg?secure=lNMGgOG2JrF4a4L0jMF-dQ%3D%3D%2C1644935151', 'is_practice_test_course': False, 'image_480x270': 'https://img-b.udemycdn.com/course/480x270/1111630_c4ba_5.jpg?secure=KH5O2qQtVXxDkbidTNZVvw%3D%3D%2C1644935151', 'published_title': 'learn-to-play-the-piano-from-scratch', 'tracking_id': '7YiNYSdKRDWug1eRr-E7-A', 'predictive_score': None, 'relevancy_score': None, 'input_features': None, 'lecture_search_result': None, 'curriculum_lectures': [], 'order_in_results': None, 'curriculum_items': [], 'headline': 'Piano lessons/ keyboard lessons for beginners. Play piano by ear, chords, reading music, improvisation, music theory', 'instructor_name': None}, {'_class': 'course', 'id': 1708482, 'title': 'The Ultimate Piano Chords Course - for Piano & Keyboard', 'url': '/course/the-ultimate-piano-chord-course-for-piano-keyboard/', 'is_paid': True, 'price': '$84.99', 'price_detail': {'amount': 84.99, 'currency': 'USD', 'price_string': '$84.99', 'currency_symbol': '$'}, 'price_serve_tracking_id': 'FVED5ALfTGCKRcfYei3w5A', 'visible_instructors': [{'_class': 'user', 'id': 25295806, 'title': 'Arthur Bird', 'name': 'Arthur', 'display_name': 'Arthur Bird', 'job_title': 'Piano Teacher, Professional Musician, Session Player', 'image_50x50': 'https://img-c.udemycdn.com ...
